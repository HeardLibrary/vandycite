# %%
import pandas as pd

# Accession numbers in images are not unique. They are clean except in cases where images involve multiple works, don't have accession numbers, etc.
# They have  Q IDs, which are also not unique.
images = pd.read_csv('images.csv', na_filter=False, dtype=str)
images = images.set_index('local_filename')

# The accession numbers are not unique and are not clean since they are just parsed from the filenames.
image_dimensions = pd.read_csv('image_dimensions.csv', na_filter=False, dtype=str)
image_dimensions = image_dimensions.set_index('name')

# The local filenames should be unique. They might possibly have been changed so aren't guaranteed to match the other dataframes.
# Generally, there is one uploaded image per work, but there are some exceptions. So the Q IDs and accession numbers are not guarantted to be unique.
commons_images = pd.read_csv('commons_images.csv', na_filter=False, dtype=str)
commons_images = commons_images.set_index('local_filename')

# This was the upload file for Wikidata, so the Q IDs should be unique. There should be a one-to-one mapping between Q IDs and accession numbers, 
# so the accession numbers should also be unique. They should also be clean since they were used as the inventory number for the Wikidata upload.
works = pd.read_csv('../works_multiprop.csv', na_filter=False, dtype=str)
works = works.set_index('inventory_number')

# %%
image_dimensions = image_dimensions.drop(image_dimensions.loc[:, 'accession':'subdir'].columns, axis='columns')

# %%
# Perform an outer join of the images and image_dimensions dataframes to capture.
combined_images = pd.merge(images, image_dimensions, how='outer', left_index=True, right_index=True)

combined_images.index.names = ['local_filename']

combined_images.head()
# Out:
#                        qid local_identifier     rank label notes kilobytes  \
# local_filename
# 1956-001.tif    Q102961253         1956.001  primary                 73531
# 1956-003.tif    Q103297456         1956.003  primary                 47806
# 1956-026.tif    Q103310082         1956.026  primary                 11861
# 1956-027.tif    Q103308843         1956.027  primary                126728
# 1956-028.tif    Q102974499         1956.028  primary                111022
#
#                height width photo_inception subdir extension
# local_filename
# 1956-001.tif     2611  4805      2020-07-23   1956       tif
# 1956-003.tif     3600  2265      2020-08-18   1956       tif
# 1956-026.tif     1702  1188      2020-07-23   1956       tif
# 1956-027.tif     5651  3826      2020-07-23   1956       tif
# 1956-028.tif     5078  3730      2020-07-23   1956       tif

# %%
commons_images.head()
# Out:
#                        qid  commons_id local_identifier  \
# local_filename
# 1984.021.tif    Q102961225  M113028886         1984.021
# 1979.0264P.tif  Q102961508  M113040378       1979.0264P
# 1993.222.tif    Q102961566  M113051913         1993.222
# 1979.0303P.tif  Q102961830  M113053575       1979.0303P
# 1973.005.tif    Q102962942  M113053895         1973.005
#
#                                                          label_en directory  \
# local_filename
# 1984.021.tif    A Conversation with Guido di Brettinoro, (Purg...      1984
# 1979.0264P.tif                          Adoration of the Sheperds      1979
# 1993.222.tif    Album painting of two men in a cottage in a mo...      1993
# 1979.0303P.tif                                      Autumn River       1979
# 1973.005.tif                                     Caney Fork Cabin      1973
#
#                rank                                         image_name  \
# local_filename
# 1984.021.tif         A Conversation with Guido di Brettinoro - Vand...
# 1979.0264P.tif       Adoration of the Sheperds - Vanderbilt Fine Ar...
# 1993.222.tif         Album painting of two men in a cottage in a mo...
# 1979.0303P.tif       Autumn River - Vanderbilt Fine Arts Gallery - ...
# 1973.005.tif         Caney Fork Cabin - Vanderbilt Fine Arts Galler...
#
#                                                     iiif_manifest  \
# local_filename
# 1984.021.tif    https://iiif-manifest.library.vanderbilt.edu/g...
# 1979.0264P.tif  https://iiif-manifest.library.vanderbilt.edu/g...
# 1993.222.tif    https://iiif-manifest.library.vanderbilt.edu/g...
# 1979.0303P.tif  https://iiif-manifest.library.vanderbilt.edu/g...
# 1973.005.tif    https://iiif-manifest.library.vanderbilt.edu/g...
#
#                                                             notes
# local_filename
# 1984.021.tif    Trial upload by script, linked by Quickstateme...
# 1979.0264P.tif
# 1993.222.tif
# 1979.0303P.tif
# 1973.005.tif

# %%
# Perform an outer join of the combined_images and commons_images dataframes.
images_with_commons = pd.merge(combined_images, commons_images, how='outer', left_index=True, right_index=True)

# Save the combined images dataframe to a CSV file.
images_with_commons.to_csv('combined_images.csv')

# %%
# This was the upload file for Wikidata, so the Q IDs should be unique. There should be a one-to-one mapping between Q IDs and accession numbers, 
# so the accession numbers should also be unique. They should also be clean since they were used as the inventory number for the Wikidata upload.
works = pd.read_csv('../works_multiprop.csv', na_filter=False, dtype=str)
works = works.set_index('qid')

artworks = pd.read_csv('artwork_metadata.csv', na_filter=False, dtype=str)
artworks = artworks.set_index('qid')

# %%
works = works.drop(works.loc[:, 'inventory_number_collection':].columns, axis='columns')
works.head()
# Out:
#                                                      label_en  \
# qid
# Q102305506                       The Christ of the Breadlines
# Q102315563                      Seated female funerary figure
# Q102315787                  Head of a Young Girl or a Goddess
# Q102949359    "I Hate You For Hitting My Mother," Minneapolis
# Q102958387  (An Imaginary) Night Attack in the War Between...
#
#                          description_en                 inventory_number_uuid  \
# qid
# Q102305506    print by Fritz Eichenberg  60965535-6F8D-4CB7-B702-D6A84E576DA3
# Q102315563   ceramics by Artist Unknown  9438F518-B646-4E12-AADD-D5FF50DF3346
# Q102315787  sculpture by Artist Unknown  B5F33FEE-A2B6-4D77-8764-C3942DC09E1B
# Q102949359  photograph by Donna Ferrato  AE86C1A8-48F0-4FD4-92D2-6DB10C878E24
# Q102958387           print by Yoshitora  B7A0A58E-8E8B-4B6A-A1E0-1EE854BA62B0
#
#            inventory_number
# qid
# Q102305506     2017.001.062
# Q102315563         1994.413
# Q102315787         1969.014
# Q102949359         2013.042
# Q102958387     1992.139 a-c

# %%
works = works.drop(works.loc[:, 'label_en':'inventory_number_uuid'].columns, axis='columns')
works.head()
# Out:
#            inventory_number
# qid
# Q102305506     2017.001.062
# Q102315563         1994.413
# Q102315787         1969.014
# Q102949359         2013.042
# Q102958387     1992.139 a-c

# %%
# Perform an outer join of the combined_images and commons_images dataframes.
works_clean = pd.merge(works, artworks, how='outer', left_index=True, right_index=True)

# Save the combined images dataframe to a CSV file.
works_clean.to_csv('works_clean.csv')
