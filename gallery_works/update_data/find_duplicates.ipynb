# %%
import pandas as pd

works_metadata = pd.read_csv('works_multiprop.csv', na_filter=False, dtype = str)
works_metadata.set_index('qid', inplace=True)

works_metadata.head()
# Out:
#                                                      label_en  \
# qid
# Q102961253  A group of muffs and other articles of dress o...
# Q103296446              A Flower Piece (after Jan van Huysum)
# Q103297456                                      Bishop Hacket
# Q103310070     The Raising of Lazarus (after Leandro Bassano)
# Q103301130  Hercules Overcoming Envy (after Peter Paul Rub...
#
#                                   description_en  \
# qid
# Q102961253            print by Wenceslaus Hollar
# Q103296446               print by Richard Earlom
# Q103297456  print by William Faithorne the elder
# Q103310070         print by John Baptist Jackson
# Q103301130           print by Christoffel Jegher
#
#                            inventory_number_uuid inventory_number  \
# qid
# Q102961253  4AD5A2D4-18A5-4DB0-80BF-50AF5249E4A1         1956.001
# Q103296446  0B667815-131F-4A8D-8E87-8BBB35056CC7         1956.002
# Q103297456  ADF8D85B-2FC2-475A-A858-683BD62E28C1         1956.003
# ...

# %%
works_metadata.loc[works_metadata.duplicated(subset = 'inventory_number')]
# Out:
# Empty DataFrame
# ...

# %%
print(works_metadata.duplicated(subset = 'inventory_number'))
# Out:
# qid
# Q102961253    False
# Q103296446    False
# Q103297456    False
# Q103310070    False
# Q103301130    False
#               ...
# Q106568640    False
# Q103300332    False
# Q109132456    False
# Q109192070    False
# Q90716090     False
# Length: 6888, dtype: bool
