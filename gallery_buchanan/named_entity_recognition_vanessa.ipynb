# %% [markdown]
# # Fine arts gallery Named Entity Recognition (NER) tests
#
#
# ## Function section
#
# This needs to be run before any of the other cells

# %%
from pathlib import Path
import requests
from time import sleep
import json
import csv
import os
from fuzzywuzzy import fuzz # fuzzy logic matching
from copy import deepcopy
from langdetect import detect
from langdetect import detect_langs
import datetime

# ----------------
# Configuration settings
# ----------------

sparql_sleep = 0.1 # number of seconds to wait between queries to SPARQL endpoint
dots_sleep = 1 # number of seconds to wait between calls to ParallelDots API
home = str(Path.home()) # gets path to home directory; supposed to work for both Win and Mac
endpoint = 'https://query.wikidata.org/sparql'
accept_media_type = 'application/json'

# Calculate the reference date retrieved value for all statements
whole_time_string_z = datetime.datetime.utcnow().isoformat() # form: 2019-12-05T15:35:04.959311
dateZ = whole_time_string_z.split('T')[0] # form 2019-12-05
ref_retrieved = dateZ + 'T00:00:00Z' # form 2019-12-05T00:00:00Z as provided by Wikidata, without leading +

# ----------------
# Utility functions
# ----------------

# Best to send a user-agent header because some Wikimedia servers don't like unidentified clients
def generate_header_dictionary(accept_media_type):
    user_agent_header = 'VanderBot/1.6 (https://github.com/HeardLibrary/linked-data/tree/master/vanderbot; mailto:steve.baskauf@vanderbilt.edu)'
    request_header_dictionary = {
        'Accept' : accept_media_type,
        'Content-Type': 'application/sparql-query',
        'User-Agent': user_agent_header
    }
    return request_header_dictionary

requestheader = generate_header_dictionary(accept_media_type)

# read from a CSV file into a list of dictionaries
def read_dict(filename):
    with open(filename, 'r', newline='', encoding='utf-8') as file_object:
        dict_object = csv.DictReader(file_object)
        array = []
        for row in dict_object:
            array.append(row)
    return array

# write a list of dictionaries to a CSV file
def write_dicts_to_csv(table, filename, fieldnames):
    with open(filename, 'w', newline='', encoding='utf-8') as csv_file_object:
        writer = csv.DictWriter(csv_file_object, fieldnames=fieldnames)
        writer.writeheader()
        for row in table:
            writer.writerow(row)

def load_credential(filename, directory):
    cred = ''
    # to change the script to look for the credential in the working directory, change the value of home to empty string
    if directory == 'home':
        home = str(Path.home()) #gets path to home directory; works for both Win and Mac
        credential_path = home + '/' + filename
    else:
        directory = 'working'
        credential_path = filename
    try:
        with open(credential_path, 'rt', encoding='utf-8') as file_object:
            cred = file_object.read()
    except:
        print(filename + ' file not found - is it in your ' + directory + ' directory?')
        exit()
    return(cred)

# find non-redundant values for a column or simple list
def non_redundant(table, column_key):
    non_redundant_list = []
    for row in table:
        found = False
        for test_item in non_redundant_list:
            if column_key == '':
                if row == test_item:
                    found = True
                    break
            else:
                if row[column_key] == test_item:
                    found = True
                    break
        if not found:
            if column_key == '':
                non_redundant_list.append(row)
            else:
                non_redundant_list.append(row[column_key])
    return non_redundant_list

# function to use in sort of simple list
def sort_funct(row):
    return row

# function to use in sort last_first names
def sort_last_first(row):
    return row['last_first']

# function to use in sort by match score
def sort_score(row):
    return row['score']

# extracts the qNumber from a Wikidata IRI
def extract_qnumber(iri):
    # pattern is http://www.wikidata.org/entity/Q6386232
    pieces = iri.split('/')
    return pieces[4]

# search label and alias
# For whatever reason, if I use the graph pattern

# wd:Q21 wdt:P31 ?class.

# England is not Q6256 (country)
# But if I use the graph pattern

#   wd:Q21 p:P31 ?statement.
#  ?statement ps:P31 ?class.

# it is ??!!
def searchLabelsAtWikidata(string, class_list):
    # create a string for the query
    query = 'select distinct ?id '
    query += '''where {
  {?id rdfs:label "''' + string + '''"@en.}
  union
  {?id skos:altLabel "''' + string + '''"@en.}
  '''
    for class_index in range(len(class_list)):
        if class_index == 0:
            query += '''{?id p:P31 ?statement.
  # ?statement ps:P31 wd:''' + class_list[class_index] + '''.}
  '''
        else:
            query += '''union
  {?id p:P31 ?statement.
  # ?statement ps:P31 wd:''' + class_list[class_index] + '''.}
  '''
    query += '''}'''
    #print(query)

    return_value = []
    # r = requests.get(endpointUrl, params={'query' : query}, headers=requestHeaderDictionary)
    r = requests.post(endpoint, data=query.encode('utf-8'), headers=generate_header_dictionary(accept_media_type))
    data = r.json()
    results = data['results']['bindings']
    for result in results:
        qid = extract_qnumber(result['id']['value'])
        return_value.append(qid)

    # delay a quarter second to avoid hitting the SPARQL endpoint too rapidly
    sleep(sparql_sleep)
    
    return return_value

def retrieve_gallery_classes():
    # create a string for the query
    # use Metropolitan Museum of Art because there are too many collections to not specify the collection.
    query = '''select distinct ?class ?label where 
      {
      # ?item wdt:P195 wd:Q160236.
      # ?item wdt:P31 ?class.
      # ?class rdfs:label ?label.
      filter(lang(?label) = 'en')
      }
      order by ?label'''

    #print(query)

    return_value = []
    print('sending query')
    r = requests.post(endpoint, data=query.encode('utf-8'), headers=generate_header_dictionary(accept_media_type))
    print('results returned')
    data = r.json()
    results = data['results']['bindings']
    for result in results:
        qid = extract_qnumber(result['class']['value'])
        label = result['label']['value']
        return_value.append({'label': label, 'qid': qid})

    # delay a quarter second to avoid hitting the SPARQL endpoint too rapidly
    sleep(sparql_sleep)
    
    return return_value

def generateNameAlternatives(name):
    # treat commas as if they were spaces
    name = name.replace(',', ' ')
    # get rid of periods
    name = name.replace('.', '')

    pieces = name.split(' ')
    
    # Remove ", Jr.", "III", etc. from end of name
    if pieces[len(pieces)-1] == 'Jr':
        pieces = pieces[0:len(pieces)-1]
        suffix = ', Jr.'
    elif pieces[len(pieces)-1] == 'II':
        pieces = pieces[0:len(pieces)-1]
        suffix = ' II'
    elif pieces[len(pieces)-1] == 'III':
        pieces = pieces[0:len(pieces)-1]
        suffix = ' III'
    elif pieces[len(pieces)-1] == 'IV':
        pieces = pieces[0:len(pieces)-1]
        suffix = ' IV'
    elif pieces[len(pieces)-1] == 'V':
        pieces = pieces[0:len(pieces)-1]
        suffix = ' V'
    elif len(pieces) > 3 and pieces[len(pieces)-2] == 'the' and pieces[len(pieces)-1] == 'elder':
        pieces = pieces[0:len(pieces)-2]
        suffix = ' the elder'
    else:
        suffix = ''

    # generate initials for all names
    initials = []
    for piece in pieces:
        # make sure first character is alphabetic
        # only fixes the case where there is one alphanumeric, but more than one is rare
        # typical cases are like (Kit) or "Kit"
        if not piece[0:1].isalpha():
            piece = piece[1:len(piece)] # remove the first non-alphabetic character
        if len(piece) > 0:
            initials.append(piece[0:1])
        
    alternatives = []
    # full name
    nameVersion = ''
    for pieceNumber in range(0, len(pieces)-1):
        nameVersion += pieces[pieceNumber] + ' '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)
    
    # full name with suffix
    if suffix != '':
        nameVersion = ''
        for pieceNumber in range(0, len(pieces)-1):
            nameVersion += pieces[pieceNumber] + ' '
        nameVersion += pieces[len(pieces)-1] + suffix
        alternatives.append(nameVersion)
    
    # first and last name with initials
    nameVersion = pieces[0] + ' '
    for pieceNumber in range(1, len(pieces)-1):
        nameVersion += initials[pieceNumber] + ' '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)
    
    # first and last name with initials and periods
    nameVersion = pieces[0] + ' '
    for pieceNumber in range(1, len(pieces)-1):
        nameVersion += initials[pieceNumber] + '. '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)

    # first and last name only
    nameVersion = pieces[0] + ' '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)

    # first initial and last name only
    nameVersion = initials[0] + ' '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)

    # first initial with period and last name only
    nameVersion = initials[0] + '. '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)

    # all name initials with last name
    nameVersion = initials[0] + ' '
    for pieceNumber in range(1, len(pieces)-1):
        nameVersion += initials[pieceNumber] + ' '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)

    # all name initials with periods with last name
    nameVersion = ''
    for pieceNumber in range(0, len(pieces)-1):
        nameVersion += initials[pieceNumber] + '. '
    nameVersion += pieces[len(pieces)-1]
    alternatives.append(nameVersion)

    # all name initials concatenated with last name
    nameVersion = ''
    for pieceNumber in range(0, len(pieces)-1):
        nameVersion += initials[pieceNumber]
    nameVersion += ' ' + pieces[len(pieces)-1]
    alternatives.append(nameVersion)
    
    # remove duplicates
    dedupe = list(set(alternatives))

    return dedupe

def searchNameAtWikidata(name):
    nameList = generateNameAlternatives(name)
    alternatives = ''
    for alternative in nameList:
        # get rid of quotes, which will break the query
        alternative = alternative.replace('"', '')
        alternative = alternative.replace("'", '')
        alternatives += '"' + alternative + '"@en\n'
    query = '''
select distinct ?item ?label where {
  VALUES ?value
  {
  ''' + alternatives + '''}
# ?item rdfs:label|skos:altLabel ?value.
# ?item rdfs:label ?label.
FILTER(lang(?label)='en')
  }
'''
    #print(query)
    #print('searching for ', name)
    results = []
    # r = requests.get(wikidataEndpointUrl, params={'query' : query}, headers=requestHeaderDictionary)
    r = requests.post(endpoint, data=query.encode('utf-8'), headers=requestheader)
    try:
        data = r.json()
        statements = data['results']['bindings']
        for statement in statements:
            wikidataIri = statement['item']['value']
            if 'label' in statement:
                name = statement['label']['value']
            else:
                name = ''
            qNumber = vbc.extract_qnumber(wikidataIri)
            results.append({'qId': qNumber, 'name': name})
    except:
        results = [{'error': r.text}]
    # delay a quarter second to avoid hitting the SPARQL endpoint too rapidly
    sleep(sparql_sleep)
    return results

def name_variant_testing(name, variant):
    # get rid of periods
    name = name.replace('.','')
    variant = variant.replace('.','')
    
    # create first names
    name_pieces = name.split(' ')
    variant_pieces = variant.split(' ')
    last_name = name_pieces[len(name_pieces)-1]
    last_variant = variant_pieces[len(variant_pieces)-1]
    if len(name_pieces) > 1:
        first_names = name[0:-(len(last_name)+1)]
    else:
        first_names = name     
    if len(variant_pieces) > 1:
        first_variants = variant[0:-(len(last_variant)+1)]
    else:
        first_variants = variant      
    #print(first_names)
    #print(first_variants)
    
    # compare first names
    # I experimented with the different ratios and I think fuzz might be best.
    ratio = fuzz.ratio(first_names, first_variants)
    #partial_ratio = fuzz.partial_ratio(first_names, first_variants)
    #sort_ratio = fuzz.token_sort_ratio(first_names, first_variants)
    #set_ratio = fuzz.token_set_ratio(first_names, first_variants)
    # print('name similarity ratio', ratio)
    #print('partial ratio', partial_ratio)
    #print('sort_ratio', sort_ratio)
    #print('set_ratio', set_ratio)

    return(ratio)

def find_surname_givens(name):
    # Get rid of periods and commas
    name = name.replace('.', '')
    name = name.replace(',', '')
    
    # Split name
    pieces = name.split(' ')
    # Must be at least a surname and something else
    if len(pieces) <= 1:
        return False
    
    # Make sure first character is alphabetic
    # only fixes the case where there is one alphanumeric, but more than one is rare
    # typical cases are like (Kit) or "Kit"    
    for piece_index in range(len(pieces)):
        if not pieces[piece_index][0:1].isalpha(): 
            pieces[piece_index] = pieces[piece_index][1:len(pieces)] # remove the first non-alphabetic character
    # Now get rid of any empty strings; could also be caused by double spaces
    for piece in pieces:
        if len(piece) == 0: # there's nothing left, get rid of piece
            pieces.remove('')
            
    # Get rid of ", Jr.", "III", etc.
    if 'Jr' in pieces:
        pieces.remove('Jr')
    if 'Sr' in pieces:
        pieces.remove('Sr')
    if 'II' in pieces:
        pieces.remove('II')
    if 'III' in pieces:
        pieces.remove('III')
    if 'IV' in pieces:
        pieces.remove('IV')
    if 'V' in pieces:
        pieces.remove('V')
    
    # Not interested unless there are at least two pieces
    if len(pieces) == 1:
        return False
    
    # Put all but last piece together again
    given_names = ''
    for piece in pieces[0:len(pieces)-2]:
        given_names += piece + ' '
    given_names += pieces[len(pieces)-2]
    
    return {'given': given_names, 'family': pieces[len(pieces)-1]}

def remove_parens(string):
    name_string = string.split('(')[0]
    return name_string.strip()

def remove_description(string):
    try:
        right_string = string.split('(')[1]
        left_string = right_string.split(')')[0]
        result = left_string.strip()
    except:
        result = ''
    return result

def reverse_names(string):
    pieces = string.split(',')
    return pieces[1].strip() + ' ' + pieces[0].strip()

# Screens for Wikidata items that are potential matches

import vb_common_code as vbc
retrieve_class_list_query = vbc.Query(pid='P31', uselabel=False, sleep=sparql_sleep)
retrieve_birth_date_query = vbc.Query(isitem=False, pid='P569', sleep=sparql_sleep)
retrieve_death_date_query = vbc.Query(isitem=False, pid='P570', sleep=sparql_sleep)

def human(qId):
    screen = True
    wdClassList = retrieve_class_list_query.single_property_values_for_item(qId)
    # if there is a class property, check if it's a human
    if len(wdClassList) != 0:
        # if it's not a human
        if wdClassList[0] != 'Q5':
            #print('*** This item is not a human!')
            screen = False
    return screen

# returns a dictionary of various descriptors of the item with Wikidata ID qId
# P106 is occupation, schema:description is filtered to be the English description
def searchWikidataDescription(qId):
    resultsDict = {}
    query = '''select distinct ?description ?orcid ?occupation where {
        optional {
            wd:'''+ qId + ''' schema:description ?description.
            FILTER(lang(?description) = 'en')
            }
        optional {
            wd:'''+ qId + ''' wdt:P106 ?occupationId.
            # ?occupationId rdfs:label ?occupation.
            FILTER(lang(?occupation) = 'en')            
            }
        optional {wd:'''+ qId + ''' wdt:P496 ?orcid.}
      }'''
    #print(query)
    r = requests.post(endpoint, data=query.encode('utf-8'), headers=requestheader)
    try:
        data = r.json()
        statements = data['results']['bindings']
        if len(statements) > 0: # if no results, the dictionary remains empty
            # Only a single description per language is allowed, so there should only be one description
            if 'description' in statements[0]:
                description = statements[0]['description']['value']
            else:
                description = ''
            resultsDict['description'] = description
            
            # Only a single ORCID is allowed, so there should only be one orcid value
            if 'orcid' in statements[0]:
                orcid = statements[0]['orcid']['value']
            else:
                orcid = ''
            resultsDict['orcid'] = orcid
            
            # if there are multiple statements, that's because there are more than one occupation
            occupationList = []
            for statement in statements:
                if 'occupation' in statement:
                    occupationList.append(statement['occupation']['value'])
            resultsDict['occupation'] = occupationList
    except:
        resultsDict = {'error': r.text}
    # delay a quarter second to avoid hitting the SPARQL endpoint too rapidly
    sleep(sparql_sleep)
    return resultsDict

def determine_era(string):
    # dates with no CE or BCE, including empty string
    if 'CE' not in string:
        value = string
        era = 'unknown'      
    else:
        if 'BCE' in string:
            value = string[0:len(string)-3].strip()
            era = 'BCE'
        else: # string ends with CE
            value = string[0:len(string)-2].strip()
            era = 'CE'
    return value, era

def determine_zeros(date):
    zero_count = 0
    for char_number in range(len(date), 0, -1):
        if date[char_number-1] == '0':
            zero_count += 1
        else:
            return zero_count

def pad_zeros_left(date_string):
    length = len(date_string)
    pad = 4-length
    return '0' * pad + date_string

def sign(era):
    if era == 'BCE':
        return '-'
    elif era == 'CE':
        return ''
    else:
        return ''

def detect_language(string):
    try:
        lang_list = detect_langs(string)
        lang_string = str(lang_list[0])
        confidence = float(lang_string[3:])
        lang = lang_string[:2]
    except: #exceptions occur when no info to decide, e.g. numbers
        lang = 'zxx'
        confidence = float(0)
    return lang, confidence
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ## 2021 fall tests
#
# These are some of the NER products that seem to be widely used: NLTK, Spacy, and ParallelDots.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
'''
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
''''''
# import spacy
# from spacy import displacy
# from collections import Counter
# first had to execute at command line:
''' Also a one-time download
python -m spacy download en_core_web_sm
'''
# import en_core_web_sm
# nlp = en_core_web_sm.load()

# Note: ParallelDots is a commercial product with a free tier. But it requires an account and API key to use.
# import paralleldots
# key = load_credential('paralleldots_api_key.txt', 'home')
# paralleldots.set_api_key(key)
# Out:
# [nltk_data] Downloading package punkt to /Users/peiyuxin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/peiyuxin/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/peiyuxin/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/peiyuxin/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ' Also a one-time download\npython -m spacy download en_core_web_sm\n'

# %% [markdown]
# # Load data
#
# Loads processed data (ones where the capitalization was corrected manually vs. raw labels)

# %%
filename = 'test_descriptions.csv'
works = read_dict(filename)

# See https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da 
# for codes used in output

# %% [markdown]
# ## NLTK
#
# NOTE: seems to depend very heavily on capitalization.

# %%
output_list = []

for work in works[3:5]:
    print('raw text:', work['label_en'])
    work_dict = {'qid': work['qid'], 'label_en': work['label_en'], 'inventory_number': work['inventory_number']}
    ne_list = []
    # https://stackoverflow.com/questions/31836058/nltk-named-entity-recognition-to-a-python-list
    tokens = nltk.word_tokenize(work['label_en'])
    print('tokens:', tokens)
    tagged_tokens = nltk.pos_tag(tokens)
    print('tagged:', tagged_tokens)
    named_entity_chunks = nltk.ne_chunk(tagged_tokens)
    print('NE chunks:', named_entity_chunks)
    
    for chunk in named_entity_chunks:
        if hasattr(chunk, 'label'):
            ne_dict = {'ne_label': chunk.label()}
            # A chunk is some kind of iterable of tuples
            # Each tuple contains (word, noun_descriptor)
            ne_string = chunk[0][0] # 0th tuple, word
            # Iterate through the rest of the tuples in the chunk
            for additional_tuple in chunk[1:len(chunk)]:
                ne_string += ' ' + additional_tuple[0]
            ne_dict['ne_string'] = ne_string
            ne_list.append(ne_dict)

            # print(chunk.label(), ' '.join(c[0] for c in chunk))
    print('NE list:', ne_list)
    work_dict['ne_list'] = ne_list
    # print(json.dumps(work_dict, indent = 2))
    
    ''' did some tests and found it basically doesn't work if lowercase
    print()
    for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(work['label_en'].lower()))):
        if hasattr(chunk, 'label'):
            print(chunk.label(), ' '.join(c[0] for c in chunk))
    print('-----------')
    '''
    output_list.append(work_dict)
    print()
print(json.dumps(output_list, indent = 2))
# Out:
# raw text: Banjovi, Bluegrass Explosion
# tokens: ['Banjovi', ',', 'Bluegrass', 'Explosion']
# tagged: [('Banjovi', 'NNP'), (',', ','), ('Bluegrass', 'NNP'), ('Explosion', 'NNP')]
# NE chunks: (S (GPE Banjovi/NNP) ,/, (PERSON Bluegrass/NNP Explosion/NNP))
# NE list: [{'ne_label': 'GPE', 'ne_string': 'Banjovi'}, {'ne_label': 'PERSON', 'ne_string': 'Bluegrass Explosion'}]
#
# raw text: BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# tokens: ['BARCELONA', "'92", ':', 'Games', 'of', 'the', 'XXV', 'Olympiad', 'Barcelona', '1992']
# tagged: [('BARCELONA', 'NNP'), ("'92", 'POS'), (':', ':'), ('Games', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('XXV', 'NNP'), ('Olympiad', 'NNP'), ('Barcelona', 'NNP'), ('1992', 'CD')]
# NE chunks: (S
#   (ORGANIZATION BARCELONA/NNP)
#   '92/POS
#   :/:
#   Games/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION XXV/NNP Olympiad/NNP)
#   Barcelona/NNP
#   1992/CD)
# NE list: [{'ne_label': 'ORGANIZATION', 'ne_string': 'BARCELONA'}, {'ne_label': 'ORGANIZATION', 'ne_string': 'XXV Olympiad'}]
#
# [
#   {
#     "qid": "Q105091628",
#     "label_en": "Banjovi, Bluegrass Explosion",
#     "inventory_number": "2000.053",
#     "ne_list": [
#       {
#         "ne_label": "GPE",
#         "ne_string": "Banjovi"
#       },
#       {
#         "ne_label": "PERSON",
#         "ne_string": "Bluegrass Explosion"
#       }
#     ]
#   },
#   {
#     "qid": "Q105091630",
#     "label_en": "BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.044",
#     "ne_list": [
#       {
#         "ne_label": "ORGANIZATION",
#         "ne_string": "BARCELONA"
#       },
#       {
#         "ne_label": "ORGANIZATION",
#         "ne_string": "XXV Olympiad"
#       }
#     ]
#   }
# ]

# %%
# There doesn't seem to be any huge improvement in performance between these unmodified strings
# and the ones where I worked on capitalization (previous cell)

filename = 'test_descriptions_unmodified.csv'
works_unmodified = read_dict(filename)

output_list = []
for work in works_unmodified:
    print(work['label_en'])
    work_dict = {'qid': work['qid'], 'label_en': work['label_en'], 'inventory_number': work['inventory_number']}
    
    # https://stackoverflow.com/questions/31836058/nltk-named-entity-recognition-to-a-python-list
    for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(work['label_en']))):
        if hasattr(chunk, 'label'):
            print(chunk.label(), ' '.join(c[0] for c in chunk))
    print('-----------')
# Out:
# B.B. King In Person (Black text)
# GPE Person
# ORGANIZATION Black
# -----------
# B.B. King In Person (purple text)
# GPE Person
# -----------
# Bah! Design
# GPE Bah
# -----------
# Banjovi, Bluegrass Explosion
# GPE Banjovi
# PERSON Bluegrass Explosion
# -----------
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# ORGANIZATION BARCELONA
# ORGANIZATION XXV Olympiad
# -----------
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# ORGANIZATION BARCELONA
# ORGANIZATION XXV Olympiad
# -----------
# BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992
# ORGANIZATION XXV Olympiad
# -----------
# Barcelona Blue #14 (Mountain Drawing)
# PERSON Barcelona
# ORGANIZATION Blue
# ORGANIZATION Mountain
# -----------
# Barcelona Blue #7 (Mountain Drawing)
# PERSON Barcelona
# ORGANIZATION Blue
# ORGANIZATION Mountain
# -----------
# Barcelona Blue #8 (Mountain Drawing)
# PERSON Barcelona
# ORGANIZATION Blue
# ORGANIZATION Mountain
# -----------
# Barcelona Blue #9 (Mountain Drawing)
# PERSON Barcelona
# ORGANIZATION Blue
# ORGANIZATION Mountain
# -----------
# Barenaked Ladies
# -----------
# Battle Scene from the Sino-Japanese War
# PERSON Battle
# ORGANIZATION Scene
# -----------
# Be A Good Neighbor-Check Out John Hartford Live from Mountain Stage, Blue Plate Music - BPM-401
# PERSON John Hartford Live
# GPE Mountain Stage
# PERSON Blue Plate Music
# -----------
# Beast, from The Marriage of Venus and Mars
# GPE Beast
# ORGANIZATION Marriage of Venus
# PERSON Mars
# -----------
# Bechtold (Dedicated book)
# GPE Bechtold
# ORGANIZATION Dedicated
# -----------
# Ben Folds Five, Jude, May 30
# PERSON Ben
# PERSON Folds Five
# PERSON Jude
# -----------
# Ben Harper and the Innocent Criminals
# PERSON Ben
# ORGANIZATION Harper
# ORGANIZATION Innocent
# -----------
# Berkhampstead - Herts.
# GPE Berkhampstead
# -----------
# Best of the best showcase April 28,1999
# -----------
# Bhutanese tangkha of Chenrazig, the Bodhisattva of Compassion
# GPE Bhutanese
# GPE Chenrazig
# ORGANIZATION Bodhisattva
# ORGANIZATION Compassion
# -----------
# Bijou Theatre
# PERSON Bijou
# -----------
# BIll Kirchen and Too Much Full Featuring Johnny and Jack
# PERSON BIll
# ORGANIZATION Kirchen
# ORGANIZATION Too
# PERSON Johnny
# PERSON Jack
# -----------
# Bill Monroe Live From Mountain Stage
# PERSON Bill
# PERSON Monroe Live
# -----------
# Birds and Pine Tree
# PERSON Pine Tree
# -----------
# Birthweek 2000: Guerrilla monster and BR2 present "Elvis meets the Beatles"
# ORGANIZATION BR2
# PERSON Elvis
# ORGANIZATION Beatles
# -----------
# Bisbee's Comedians
# GPE Bisbee
# -----------
# Bize II, from American Abstract Artists 75th Anniversary Print Portfolio
# PERSON Bize
# GPE II
# GPE American
# ORGANIZATION Abstract
# -----------
# Blue glass object with stopper
# GPE Blue
# -----------
# Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster
# GPE Blue
# PERSON Festival Ryman Auditorium
# PERSON Hatch Show Print Poster
# -----------
# Blue Mountain
# PERSON Blue
# ORGANIZATION Mountain
# -----------
# Blue Surge
# PERSON Blue
# -----------
# Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12
# PERSON Bluebird
# ORGANIZATION Cafe
# ORGANIZATION Rounds
# PERSON Ellen Britton
# -----------
# Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999
# PERSON Bluegrass Festival
# ORGANIZATION Karl Shiflett
# -----------
# Bluegrass Night at the Ryman
# PERSON Bluegrass
# ORGANIZATION Night
# ORGANIZATION Ryman
# -----------
# Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster
# PERSON Bob
# PERSON Delevante Porchlight Record
# PERSON Hatch Show Print Poster
# -----------
# Bombastic Plastic
# PERSON Bombastic
# ORGANIZATION Plastic
# -----------
# Bomber Records presents Dispatch
# -----------
# Bomber Records Presents Dispatch
# -----------
# Bomber Records Presents Dispatch
# -----------
# Bomber records presents Dispatch- Coming Soon
# -----------

# %% [markdown]
# ## Spacy
#
# Results were fairly similar between the cleaned up capitalization and the raw label strings
#
# That makes me think that Spacy is relatively insensite to capitalization.

# %%
output_list = []
for work in works:
    print(work['label_en'])
    work_dict = {'qid': work['qid'], 'label_en': work['label_en'], 'inventory_number': work['inventory_number']}
    
    # https://www.analyticsvidhya.com/blog/2021/06/nlp-application-named-entity-recognition-ner-in-python-with-spacy/
    result = nlp(work['label_en'])
    for entity in result.ents:
        print(entity.text, entity.label_)
    print()
    
    
    # results were somewhat worse when using all lower case
    result = nlp(work['label_en'].lower())
    for entity in result.ents:
        print(entity.text, entity.label_)
    print()

    print('-----------')
# Out:
# B.B. King in person (Black text)
# B.B. King PERSON
#
#
# -----------
# B.B. King in person (purple text)
# B.B. King PERSON
#
#
# -----------
# bah! design
#
#
# -----------
# Banjovi, Bluegrass Explosion
#
#
# -----------
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA ORG
# 1992 DATE
#
# barcelona ORG
# 92 CARDINAL
# 1992 DATE
#
# -----------
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA ORG
# 1992 DATE
#
# barcelona ORG
# 92 CARDINAL
# 1992 DATE
#
# -----------
# BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992
# 92 CARDINAL
# 1992 DATE
#
# 92 CARDINAL
# 1992 DATE
#
# -----------
# Barcelona blue #14 (mountain drawing)
# Barcelona GPE
# 14 MONEY
#
# barcelona blue # ORG
#
# -----------
# Barcelona Blue #7 (Mountain Drawing)
# Barcelona Blue #7 ORG
#
# barcelona blue #7 ORG
#
# -----------
# Barcelona Blue #8 (Mountain Drawing)
# Barcelona Blue #8 ORG
#
# barcelona blue #8 ORG
#
# -----------
# Barcelona Blue #9 (Mountain Drawing)
# Barcelona Blue #9 ORG
#
# barcelona blue #9 ORG
#
# -----------
# Barenaked Ladies
#
#
# -----------
# battle scene from the Sino-Japanese War
# Sino-Japanese NORP
#
# sino-japanese NORP
#
# -----------
# be a good neighbor - check Out John Hartford live from Mountain Stage, Blue Plate Music - BPM-401
# John Hartford PERSON
# Mountain Stage GPE
#
# john hartford PERSON
#
# -----------
# beast, from the marriage of Venus and Mars
# Venus LOC
# Mars LOC
#
#
# -----------
# Bechtold (dedicated book)
#
#
# -----------
# Ben Folds Five, Jude, May 30
# Ben Folds PERSON
# Jude PERSON
# May 30 DATE
#
# ben PERSON
# five CARDINAL
# 30 CARDINAL
#
# -----------
# Ben Harper and the Innocent Criminals
# Ben Harper PERSON
#
# ben PERSON
#
# -----------
# Berkhampstead - Herts.
#
#
# -----------
# best of the best showcase April 28,1999
# April 28,1999 DATE
#
# april 28,1999 DATE
#
# -----------
# Bhutanese tangkha of Chenrazig, the bodhisattva of compassion
# Bhutanese NORP
# Chenrazig GPE
#
# chenrazig GPE
#
# -----------
# Bijou Theatre
# Bijou Theatre ORG
#
# bijou theatre ORG
#
# -----------
# BIll Kirchen and Too Much Full Featuring Johnny and Jack
# BIll Kirchen PERSON
# Too Much Full Featuring ORG
# Johnny PERSON
# Jack PERSON
#
# bill kirchen PERSON
# johnny PERSON
# jack PERSON
#
# -----------
# Bill Monroe live from Mountain Stage
# Bill Monroe PERSON
# Mountain Stage GPE
#
# bill monroe PERSON
#
# -----------
# birds and pine tree
#
#
# -----------
# Birthweek 2000: Guerrilla monster and BR2 present "Elvis meets the Beatles"
# Birthweek 2000 DATE
# BR2 ORG
#
# 2000 DATE
#
# -----------
# Bisbee's Comedians
# Bisbee ORG
# Comedians NORP
#
# bisbee ORG
#
# -----------
# Bize II, from American Abstract Artists 75th Anniversary Print Portfolio
# American Abstract Artists 75th ORG
#
# american NORP
# 75th ORDINAL
#
# -----------
# Blue glass object with stopper
#
#
# -----------
# Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster
# Festival Ryman Auditorium PERSON
# May 7-8-9 1999 DATE
# Hatch Show Print WORK_OF_ART
#
# blue grass ORG
# 7-8-9 1999 CARDINAL
#
# -----------
# Blue Mountain
# Blue Mountain ORG
#
# blue mountain ORG
#
# -----------
# Blue Surge
# Blue Surge ORG
#
# blue surge ORG
#
# -----------
# Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12
# Bluebird Cafe Presents The Rounds Bros. PERSON
# Ellen Britton PERSON
# Sunday March 12 DATE
#
# ellen britton PERSON
# sunday march 12 DATE
#
# -----------
# Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999
# Karl Shiflett PERSON
# May 28-30, 1999 DATE
#
# karl shiflett PERSON
# 28-30 CARDINAL
#
# -----------
# Bluegrass Night at the Ryman
#
#
# -----------
# Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster
# Bob Delevante Porchlight Record PERSON
# Hatch Show Print WORK_OF_ART
#
# bob delevante PERSON
# 3,1999 CARDINAL
#
# -----------
# Bombastic Plastic
# Bombastic Plastic ORG
#
#
# -----------
# Bomber Records presents Dispatch
# Bomber Records ORG
# Dispatch PERSON
#
# bomber records ORG
#
# -----------
# Bomber Records Presents Dispatch
# Bomber Records Presents Dispatch ORG
#
# bomber records ORG
#
# -----------
# Bomber Records Presents Dispatch
# Bomber Records Presents Dispatch ORG
#
# bomber records ORG
#
# -----------
# Bomber records presents Dispatch- Coming Soon
#
#
# -----------

# %%
filename = 'test_descriptions_unmodified.csv'
works_unmodified = read_dict(filename)

for work in works_unmodified:
    print(work['label_en'])
    
    # https://www.analyticsvidhya.com/blog/2021/06/nlp-application-named-entity-recognition-ner-in-python-with-spacy/
    result = nlp(work['label_en'])
    for entity in result.ents:
        print(entity.text, entity.label_)
    print('-----------')
# Out:
# B.B. King In Person (Black text)
# B.B. King PERSON
# -----------
# B.B. King In Person (purple text)
# B.B. King PERSON
# -----------
# Bah! Design
# -----------
# Banjovi, Bluegrass Explosion
# -----------
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA ORG
# 1992 DATE
# -----------
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA ORG
# 1992 DATE
# -----------
# BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992
# 92 CARDINAL
# 1992 DATE
# -----------
# Barcelona Blue #14 (Mountain Drawing)
# Barcelona Blue # ORG
# -----------
# Barcelona Blue #7 (Mountain Drawing)
# Barcelona Blue #7 ORG
# -----------
# Barcelona Blue #8 (Mountain Drawing)
# Barcelona Blue #8 ORG
# -----------
# Barcelona Blue #9 (Mountain Drawing)
# Barcelona Blue #9 ORG
# -----------
# Barenaked Ladies
# -----------
# Battle Scene from the Sino-Japanese War
# Battle Scene PERSON
# Sino-Japanese NORP
# -----------
# Be A Good Neighbor-Check Out John Hartford Live from Mountain Stage, Blue Plate Music - BPM-401
# Mountain Stage GPE
# -----------
# Beast, from The Marriage of Venus and Mars
# The Marriage of Venus ORG
# Mars LOC
# -----------
# Bechtold (Dedicated book)
# Bechtold (Dedicated book ORG
# -----------
# Ben Folds Five, Jude, May 30
# Ben Folds PERSON
# Jude PERSON
# May 30 DATE
# -----------
# Ben Harper and the Innocent Criminals
# Ben Harper PERSON
# -----------
# Berkhampstead - Herts.
# -----------
# Best of the best showcase April 28,1999
# April 28,1999 DATE
# -----------
# Bhutanese tangkha of Chenrazig, the Bodhisattva of Compassion
# Bhutanese NORP
# Chenrazig GPE
# the Bodhisattva of Compassion ORG
# -----------
# Bijou Theatre
# Bijou Theatre ORG
# -----------
# BIll Kirchen and Too Much Full Featuring Johnny and Jack
# BIll Kirchen PERSON
# Too Much Full Featuring ORG
# Johnny PERSON
# Jack PERSON
# -----------
# Bill Monroe Live From Mountain Stage
# Bill Monroe Live PERSON
# -----------
# Birds and Pine Tree
# Pine Tree ORG
# -----------
# Birthweek 2000: Guerrilla monster and BR2 present "Elvis meets the Beatles"
# Birthweek 2000 DATE
# BR2 ORG
# -----------
# Bisbee's Comedians
# Bisbee ORG
# Comedians NORP
# -----------
# Bize II, from American Abstract Artists 75th Anniversary Print Portfolio
# American Abstract Artists 75th ORG
# -----------
# Blue glass object with stopper
# -----------
# Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster
# Festival Ryman Auditorium PERSON
# May 7-8-9 1999 DATE
# Hatch Show Print WORK_OF_ART
# -----------
# Blue Mountain
# Blue Mountain ORG
# -----------
# Blue Surge
# Blue Surge ORG
# -----------
# Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12
# Bluebird Cafe Presents The Rounds Bros. PERSON
# Ellen Britton PERSON
# Sunday March 12 DATE
# -----------
# Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999
# Karl Shiflett PERSON
# May 28-30, 1999 DATE
# -----------
# Bluegrass Night at the Ryman
# -----------
# Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster
# Bob Delevante Porchlight Record PERSON
# Hatch Show Print WORK_OF_ART
# -----------
# Bombastic Plastic
# Bombastic Plastic ORG
# -----------
# Bomber Records presents Dispatch
# Bomber Records ORG
# Dispatch PERSON
# -----------
# Bomber Records Presents Dispatch
# Bomber Records Presents Dispatch ORG
# -----------
# Bomber Records Presents Dispatch
# Bomber Records Presents Dispatch ORG
# -----------
# Bomber records presents Dispatch- Coming Soon
# -----------

# %% [markdown]
# ## Parallel Dots API
#
# NOTE: Seems to be relatively insensitive to case
#
# Cleaned test set:

# %%
output_list = []
for work in works:
    print(work['label_en'])
    work_dict = {'qid': work['qid'], 'label_en': work['label_en'], 'inventory_number': work['inventory_number']}
    named_entities = paralleldots.ner(work['label_en'])
    work_dict['named_entities'] = named_entities
    output_list.append(work_dict)
    sleep(dots_sleep)
out_text = json.dumps(output_list, indent = 2)
print(out_text)
# Out:
# B.B. King in person (Black text)
# B.B. King in person (purple text)
# bah! design
# Banjovi, Bluegrass Explosion
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992
# Barcelona blue #14 (mountain drawing)
# Barcelona Blue #7 (Mountain Drawing)
# Barcelona Blue #8 (Mountain Drawing)
# Barcelona Blue #9 (Mountain Drawing)
# Barenaked Ladies
# battle scene from the Sino-Japanese War
# be a good neighbor - check Out John Hartford live from Mountain Stage, Blue Plate Music - BPM-401
# beast, from the marriage of Venus and Mars
# Bechtold (dedicated book)
# Ben Folds Five, Jude, May 30
# Ben Harper and the Innocent Criminals
# Berkhampstead - Herts.
# best of the best showcase April 28,1999
# Bhutanese tangkha of Chenrazig, the bodhisattva of compassion
# Bijou Theatre
# BIll Kirchen and Too Much Full Featuring Johnny and Jack
# Bill Monroe live from Mountain Stage
# birds and pine tree
# Birthweek 2000: Guerrilla monster and BR2 present "Elvis meets the Beatles"
# Bisbee's Comedians
# Bize II, from American Abstract Artists 75th Anniversary Print Portfolio
# Blue glass object with stopper
# Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster
# Blue Mountain
# Blue Surge
# Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12
# Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999
# Bluegrass Night at the Ryman
# Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster
# Bombastic Plastic
# Bomber Records presents Dispatch
# Bomber Records Presents Dispatch
# Bomber Records Presents Dispatch
# Bomber records presents Dispatch- Coming Soon
# [
#   {
#     "qid": "Q105091625",
#     "label_en": "B.B. King in person (Black text)",
#     "inventory_number": "2001.167",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091626",
#     "label_en": "B.B. King in person (purple text)",
#     "inventory_number": "2001.156",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091627",
#     "label_en": "bah! design",
#     "inventory_number": "2000.058",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bah",
#           "category": "group",
#           "confidence_score": 0.4515140355
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091628",
#     "label_en": "Banjovi, Bluegrass Explosion",
#     "inventory_number": "2000.053",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Banjovi",
#           "category": "name",
#           "confidence_score": 0.4666374028
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091630",
#     "label_en": "BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.044",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BARCELONA",
#           "category": "group",
#           "confidence_score": 0.593595624
#         },
#         {
#           "name": "XXV Olympiad Barcelona",
#           "category": "group",
#           "confidence_score": 0.5632660091
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091631",
#     "label_en": "BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.045",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BARCELONA",
#           "category": "group",
#           "confidence_score": 0.593595624
#         },
#         {
#           "name": "XXV Olympiad Barcelona",
#           "category": "group",
#           "confidence_score": 0.5632660091
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091632",
#     "label_en": "BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.043",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BARCELONA",
#           "category": "group",
#           "confidence_score": 0.8035004139
#         },
#         {
#           "name": "XXV Olympiad Barcelona",
#           "category": "group",
#           "confidence_score": 0.584798644
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091633",
#     "label_en": "Barcelona blue #14 (mountain drawing)",
#     "inventory_number": "1996.073",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona blue",
#           "category": "group",
#           "confidence_score": 0.7506469488
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091634",
#     "label_en": "Barcelona Blue #7 (Mountain Drawing)",
#     "inventory_number": "1996.071",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona Blue",
#           "category": "group",
#           "confidence_score": 0.8863239884
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091635",
#     "label_en": "Barcelona Blue #8 (Mountain Drawing)",
#     "inventory_number": "1996.072",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona Blue",
#           "category": "group",
#           "confidence_score": 0.8720289767
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091636",
#     "label_en": "Barcelona Blue #9 (Mountain Drawing)",
#     "inventory_number": "1996.074",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona Blue",
#           "category": "group",
#           "confidence_score": 0.8726813197
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091637",
#     "label_en": "Barenaked Ladies",
#     "inventory_number": "2001.108",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091643",
#     "label_en": "battle scene from the Sino-Japanese War",
#     "inventory_number": "1972.048",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091644",
#     "label_en": "be a good neighbor - check Out John Hartford live from Mountain Stage, Blue Plate Music - BPM-401",
#     "inventory_number": "2001.022",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "John Hartford",
#           "category": "name",
#           "confidence_score": 0.7455496192
#         },
#         {
#           "name": "Mountain Stage",
#           "category": "place",
#           "confidence_score": 0.6131098568
#         },
#         {
#           "name": "Blue Plate",
#           "category": "place",
#           "confidence_score": 0.7622876167
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091645",
#     "label_en": "beast, from the marriage of Venus and Mars",
#     "inventory_number": "2016.004",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Venus",
#           "category": "place",
#           "confidence_score": 0.3331614137
#         },
#         {
#           "name": "Mars",
#           "category": "place",
#           "confidence_score": 0.3910125196
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091646",
#     "label_en": "Bechtold (dedicated book)",
#     "inventory_number": "1996.032",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bechtold",
#           "category": "name",
#           "confidence_score": 0.9539462924
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091647",
#     "label_en": "Ben Folds Five, Jude, May 30",
#     "inventory_number": "2000.031",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Ben Folds",
#           "category": "name",
#           "confidence_score": 0.9499144256
#         },
#         {
#           "name": "Jude",
#           "category": "name",
#           "confidence_score": 0.7599830031
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091648",
#     "label_en": "Ben Harper and the Innocent Criminals",
#     "inventory_number": "2001.122",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Ben Harper",
#           "category": "name",
#           "confidence_score": 0.9510113001
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091649",
#     "label_en": "Berkhampstead - Herts.",
#     "inventory_number": "1979.0131",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Berkhampstead",
#           "category": "place",
#           "confidence_score": 0.4688213468
#         },
#         {
#           "name": "Herts",
#           "category": "group",
#           "confidence_score": 0.6593085527
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091650",
#     "label_en": "best of the best showcase April 28,1999",
#     "inventory_number": "2000.012",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091651",
#     "label_en": "Bhutanese tangkha of Chenrazig, the bodhisattva of compassion",
#     "inventory_number": "2004.043",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bhutanese",
#           "category": "place",
#           "confidence_score": 0.7450038195
#         },
#         {
#           "name": "Chenrazig",
#           "category": "place",
#           "confidence_score": 0.4946367443
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091652",
#     "label_en": "Bijou Theatre",
#     "inventory_number": "2001.092",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bijou Theatre",
#           "category": "group",
#           "confidence_score": 0.6250170171
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091653",
#     "label_en": "BIll Kirchen and Too Much Full Featuring Johnny and Jack",
#     "inventory_number": "2001.153",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BIll Kirchen",
#           "category": "name",
#           "confidence_score": 0.8642571867
#         },
#         {
#           "name": "Johnny",
#           "category": "name",
#           "confidence_score": 0.5202775002
#         },
#         {
#           "name": "Jack",
#           "category": "name",
#           "confidence_score": 0.6613280177
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091654",
#     "label_en": "Bill Monroe live from Mountain Stage",
#     "inventory_number": "2000.025",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bill Monroe",
#           "category": "name",
#           "confidence_score": 0.923684597
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091655",
#     "label_en": "birds and pine tree",
#     "inventory_number": "1979.01",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091656",
#     "label_en": "Birthweek 2000: Guerrilla monster and BR2 present \"Elvis meets the Beatles\"",
#     "inventory_number": "2001.088",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Elvis",
#           "category": "name",
#           "confidence_score": 0.6291120648
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091657",
#     "label_en": "Bisbee's Comedians",
#     "inventory_number": "2001.174",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bisbee",
#           "category": "group",
#           "confidence_score": 0.7296882272
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091658",
#     "label_en": "Bize II, from American Abstract Artists 75th Anniversary Print Portfolio",
#     "inventory_number": "2015.038n",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bize II",
#           "category": "group",
#           "confidence_score": 0.587120533
#         },
#         {
#           "name": "American Abstract Artists",
#           "category": "group",
#           "confidence_score": 0.6716475785
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091659",
#     "label_en": "Blue glass object with stopper",
#     "inventory_number": "1979.1000P",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091660",
#     "label_en": "Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster",
#     "inventory_number": "2000.009",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Hatch",
#           "category": "name",
#           "confidence_score": 0.4638870656
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091662",
#     "label_en": "Blue Mountain",
#     "inventory_number": "2001.102",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Blue Mountain",
#           "category": "place",
#           "confidence_score": 0.3706608862
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091663",
#     "label_en": "Blue Surge",
#     "inventory_number": "1984.015",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091664",
#     "label_en": "Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12",
#     "inventory_number": "2001.033",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bluebird Cafe",
#           "category": "group",
#           "confidence_score": 0.7429014146
#         },
#         {
#           "name": "Rounds Bros",
#           "category": "group",
#           "confidence_score": 0.7720320225
#         },
#         {
#           "name": "Ellen Britton",
#           "category": "name",
#           "confidence_score": 0.9703733623
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091665",
#     "label_en": "Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999",
#     "inventory_number": "2000.038",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bluegrass Festival",
#           "category": "group",
#           "confidence_score": 0.5796358883
#         },
#         {
#           "name": "Karl Shiflett",
#           "category": "name",
#           "confidence_score": 0.9522703588
#         },
#         {
#           "name": "Big Country Show",
#           "category": "group",
#           "confidence_score": 0.557348907
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091666",
#     "label_en": "Bluegrass Night at the Ryman",
#     "inventory_number": "2001.106",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Ryman",
#           "category": "group",
#           "confidence_score": 0.5382829905
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091667",
#     "label_en": "Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster",
#     "inventory_number": "2000.081",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bob Delevante Porchlight",
#           "category": "name",
#           "confidence_score": 0.732592086
#         },
#         {
#           "name": "Hatch",
#           "category": "name",
#           "confidence_score": 0.8385927677
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091668",
#     "label_en": "Bombastic Plastic",
#     "inventory_number": "2001.134",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091669",
#     "label_en": "Bomber Records presents Dispatch",
#     "inventory_number": "2001.016",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Dispatch",
#           "category": "group",
#           "confidence_score": 0.6728092432
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091670",
#     "label_en": "Bomber Records Presents Dispatch",
#     "inventory_number": "2001.08",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091671",
#     "label_en": "Bomber Records Presents Dispatch",
#     "inventory_number": "2001.079",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091672",
#     "label_en": "Bomber records presents Dispatch- Coming Soon",
#     "inventory_number": "2001.053",
#     "named_entities": {
#       "entities": []
#     }
#   }
# ]

# %%
output_list = []
for work in works:
    print(work['label_en'])
    work_dict = {'qid': work['qid'], 'label_en': work['label_en'], 'inventory_number': work['inventory_number']}
    named_entities = paralleldots.ner(work['label_en'].lower())
    work_dict['named_entities'] = named_entities
    output_list.append(work_dict)
    sleep(dots_sleep)
out_text = json.dumps(output_list, indent = 2)
print(out_text)
# Out:
# B.B. King in person (Black text)
# B.B. King in person (purple text)
# bah! design
# Banjovi, Bluegrass Explosion
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992
# Barcelona blue #14 (mountain drawing)
# Barcelona Blue #7 (Mountain Drawing)
# Barcelona Blue #8 (Mountain Drawing)
# Barcelona Blue #9 (Mountain Drawing)
# Barenaked Ladies
# battle scene from the Sino-Japanese War
# be a good neighbor - check Out John Hartford live from Mountain Stage, Blue Plate Music - BPM-401
# beast, from the marriage of Venus and Mars
# Bechtold (dedicated book)
# Ben Folds Five, Jude, May 30
# Ben Harper and the Innocent Criminals
# Berkhampstead - Herts.
# best of the best showcase April 28,1999
# Bhutanese tangkha of Chenrazig, the bodhisattva of compassion
# Bijou Theatre
# BIll Kirchen and Too Much Full Featuring Johnny and Jack
# Bill Monroe live from Mountain Stage
# birds and pine tree
# Birthweek 2000: Guerrilla monster and BR2 present "Elvis meets the Beatles"
# Bisbee's Comedians
# Bize II, from American Abstract Artists 75th Anniversary Print Portfolio
# Blue glass object with stopper
# Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster
# Blue Mountain
# Blue Surge
# Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12
# Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999
# Bluegrass Night at the Ryman
# Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster
# Bombastic Plastic
# Bomber Records presents Dispatch
# Bomber Records Presents Dispatch
# Bomber Records Presents Dispatch
# Bomber records presents Dispatch- Coming Soon
# [
#   {
#     "qid": "Q105091625",
#     "label_en": "B.B. King in person (Black text)",
#     "inventory_number": "2001.167",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091626",
#     "label_en": "B.B. King in person (purple text)",
#     "inventory_number": "2001.156",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091627",
#     "label_en": "bah! design",
#     "inventory_number": "2000.058",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bah",
#           "category": "group",
#           "confidence_score": 0.4515140355
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091628",
#     "label_en": "Banjovi, Bluegrass Explosion",
#     "inventory_number": "2000.053",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "banjovi",
#           "category": "name",
#           "confidence_score": 0.338021636
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091630",
#     "label_en": "BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.044",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "barcelona",
#           "category": "group",
#           "confidence_score": 0.8147644401
#         },
#         {
#           "name": "xxv olympiad barcelona",
#           "category": "group",
#           "confidence_score": 0.5945980748
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091631",
#     "label_en": "BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.045",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "barcelona",
#           "category": "group",
#           "confidence_score": 0.8147644401
#         },
#         {
#           "name": "xxv olympiad barcelona",
#           "category": "group",
#           "confidence_score": 0.5945980748
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091632",
#     "label_en": "BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.043",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "barcelona",
#           "category": "group",
#           "confidence_score": 0.9543437362
#         },
#         {
#           "name": "xxv olympiad barcelona",
#           "category": "group",
#           "confidence_score": 0.5648340185
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091633",
#     "label_en": "Barcelona blue #14 (mountain drawing)",
#     "inventory_number": "1996.073",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "barcelona blue",
#           "category": "group",
#           "confidence_score": 0.7517158091
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091634",
#     "label_en": "Barcelona Blue #7 (Mountain Drawing)",
#     "inventory_number": "1996.071",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "barcelona blue",
#           "category": "group",
#           "confidence_score": 0.8041559458
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091635",
#     "label_en": "Barcelona Blue #8 (Mountain Drawing)",
#     "inventory_number": "1996.072",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "barcelona blue",
#           "category": "group",
#           "confidence_score": 0.7821881473
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091636",
#     "label_en": "Barcelona Blue #9 (Mountain Drawing)",
#     "inventory_number": "1996.074",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "barcelona blue",
#           "category": "group",
#           "confidence_score": 0.7978914082
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091637",
#     "label_en": "Barenaked Ladies",
#     "inventory_number": "2001.108",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091643",
#     "label_en": "battle scene from the Sino-Japanese War",
#     "inventory_number": "1972.048",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091644",
#     "label_en": "be a good neighbor - check Out John Hartford live from Mountain Stage, Blue Plate Music - BPM-401",
#     "inventory_number": "2001.022",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "john hartford",
#           "category": "name",
#           "confidence_score": 0.7420555651
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091645",
#     "label_en": "beast, from the marriage of Venus and Mars",
#     "inventory_number": "2016.004",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "mars",
#           "category": "place",
#           "confidence_score": 0.7034978867
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091646",
#     "label_en": "Bechtold (dedicated book)",
#     "inventory_number": "1996.032",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bechtold",
#           "category": "name",
#           "confidence_score": 0.9310974479
#         },
#         {
#           "name": "dedicated book",
#           "category": "group",
#           "confidence_score": 0.6238348186
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091647",
#     "label_en": "Ben Folds Five, Jude, May 30",
#     "inventory_number": "2000.031",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "ben folds",
#           "category": "name",
#           "confidence_score": 0.9024589956
#         },
#         {
#           "name": "jude",
#           "category": "name",
#           "confidence_score": 0.8011199832
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091648",
#     "label_en": "Ben Harper and the Innocent Criminals",
#     "inventory_number": "2001.122",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "ben harper",
#           "category": "name",
#           "confidence_score": 0.9307046235
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091649",
#     "label_en": "Berkhampstead - Herts.",
#     "inventory_number": "1979.0131",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "berkhampstead",
#           "category": "place",
#           "confidence_score": 0.7968658209
#         },
#         {
#           "name": "herts",
#           "category": "group",
#           "confidence_score": 0.6995375752
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091650",
#     "label_en": "best of the best showcase April 28,1999",
#     "inventory_number": "2000.012",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091651",
#     "label_en": "Bhutanese tangkha of Chenrazig, the bodhisattva of compassion",
#     "inventory_number": "2004.043",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bhutanese",
#           "category": "place",
#           "confidence_score": 0.6869729161
#         },
#         {
#           "name": "chenrazig",
#           "category": "place",
#           "confidence_score": 0.6179556251
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091652",
#     "label_en": "Bijou Theatre",
#     "inventory_number": "2001.092",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bijou theatre",
#           "category": "group",
#           "confidence_score": 0.3828013241
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091653",
#     "label_en": "BIll Kirchen and Too Much Full Featuring Johnny and Jack",
#     "inventory_number": "2001.153",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bill kirchen",
#           "category": "name",
#           "confidence_score": 0.8142542541
#         },
#         {
#           "name": "johnny",
#           "category": "name",
#           "confidence_score": 0.5513493419
#         },
#         {
#           "name": "jack",
#           "category": "name",
#           "confidence_score": 0.7207772136
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091654",
#     "label_en": "Bill Monroe live from Mountain Stage",
#     "inventory_number": "2000.025",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bill monroe",
#           "category": "name",
#           "confidence_score": 0.9304503202
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091655",
#     "label_en": "birds and pine tree",
#     "inventory_number": "1979.01",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091656",
#     "label_en": "Birthweek 2000: Guerrilla monster and BR2 present \"Elvis meets the Beatles\"",
#     "inventory_number": "2001.088",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "elvis",
#           "category": "name",
#           "confidence_score": 0.4477550387
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091657",
#     "label_en": "Bisbee's Comedians",
#     "inventory_number": "2001.174",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bisbee",
#           "category": "group",
#           "confidence_score": 0.7581710219
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091658",
#     "label_en": "Bize II, from American Abstract Artists 75th Anniversary Print Portfolio",
#     "inventory_number": "2015.038n",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bize ii",
#           "category": "name",
#           "confidence_score": 0.6137130111
#         },
#         {
#           "name": "american",
#           "category": "place",
#           "confidence_score": 0.9502041936
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091659",
#     "label_en": "Blue glass object with stopper",
#     "inventory_number": "1979.1000P",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091660",
#     "label_en": "Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster",
#     "inventory_number": "2000.009",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091662",
#     "label_en": "Blue Mountain",
#     "inventory_number": "2001.102",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091663",
#     "label_en": "Blue Surge",
#     "inventory_number": "1984.015",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091664",
#     "label_en": "Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12",
#     "inventory_number": "2001.033",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bluebird cafe",
#           "category": "group",
#           "confidence_score": 0.5967952907
#         },
#         {
#           "name": "ellen britton",
#           "category": "name",
#           "confidence_score": 0.9661864936
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091665",
#     "label_en": "Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999",
#     "inventory_number": "2000.038",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "karl shiflett",
#           "category": "name",
#           "confidence_score": 0.9087688029
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091666",
#     "label_en": "Bluegrass Night at the Ryman",
#     "inventory_number": "2001.106",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "ryman",
#           "category": "place",
#           "confidence_score": 0.4197948575
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091667",
#     "label_en": "Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster",
#     "inventory_number": "2000.081",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "bob delevante porchlight",
#           "category": "name",
#           "confidence_score": 0.7979426781
#         },
#         {
#           "name": "hatch",
#           "category": "name",
#           "confidence_score": 0.4573250413
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091668",
#     "label_en": "Bombastic Plastic",
#     "inventory_number": "2001.134",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091669",
#     "label_en": "Bomber Records presents Dispatch",
#     "inventory_number": "2001.016",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091670",
#     "label_en": "Bomber Records Presents Dispatch",
#     "inventory_number": "2001.08",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091671",
#     "label_en": "Bomber Records Presents Dispatch",
#     "inventory_number": "2001.079",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091672",
#     "label_en": "Bomber records presents Dispatch- Coming Soon",
#     "inventory_number": "2001.053",
#     "named_entities": {
#       "entities": []
#     }
#   }
# ]

# %%
filename = 'test_descriptions_unmodified.csv'
works_unmodified = read_dict(filename)

output_list = []
for work in works_unmodified:
    print(work['label_en'])
    work_dict = {'qid': work['qid'], 'label_en': work['label_en'], 'inventory_number': work['inventory_number']}
    named_entities = paralleldots.ner(work['label_en'])
    work_dict['named_entities'] = named_entities
    output_list.append(work_dict)
    sleep(dots_sleep)
out_text = json.dumps(output_list, indent = 2)
print(out_text)
# Out:
# B.B. King In Person (Black text)
# B.B. King In Person (purple text)
# Bah! Design
# Banjovi, Bluegrass Explosion
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992
# BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992
# Barcelona Blue #14 (Mountain Drawing)
# Barcelona Blue #7 (Mountain Drawing)
# Barcelona Blue #8 (Mountain Drawing)
# Barcelona Blue #9 (Mountain Drawing)
# Barenaked Ladies
# Battle Scene from the Sino-Japanese War
# Be A Good Neighbor-Check Out John Hartford Live from Mountain Stage, Blue Plate Music - BPM-401
# Beast, from The Marriage of Venus and Mars
# Bechtold (Dedicated book)
# Ben Folds Five, Jude, May 30
# Ben Harper and the Innocent Criminals
# Berkhampstead - Herts.
# Best of the best showcase April 28,1999
# Bhutanese tangkha of Chenrazig, the Bodhisattva of Compassion
# Bijou Theatre
# BIll Kirchen and Too Much Full Featuring Johnny and Jack
# Bill Monroe Live From Mountain Stage
# Birds and Pine Tree
# Birthweek 2000: Guerrilla monster and BR2 present "Elvis meets the Beatles"
# Bisbee's Comedians
# Bize II, from American Abstract Artists 75th Anniversary Print Portfolio
# Blue glass object with stopper
# Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster
# Blue Mountain
# Blue Surge
# Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12
# Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999
# Bluegrass Night at the Ryman
# Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster
# Bombastic Plastic
# Bomber Records presents Dispatch
# Bomber Records Presents Dispatch
# Bomber Records Presents Dispatch
# Bomber records presents Dispatch- Coming Soon
# [
#   {
#     "qid": "Q105091625",
#     "label_en": "B.B. King In Person (Black text)",
#     "inventory_number": "2001.167",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091626",
#     "label_en": "B.B. King In Person (purple text)",
#     "inventory_number": "2001.156",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091627",
#     "label_en": "Bah! Design",
#     "inventory_number": "2000.058",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bah",
#           "category": "name",
#           "confidence_score": 0.3246270716
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091628",
#     "label_en": "Banjovi, Bluegrass Explosion",
#     "inventory_number": "2000.053",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Banjovi",
#           "category": "name",
#           "confidence_score": 0.4666374028
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091630",
#     "label_en": "BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.044",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BARCELONA",
#           "category": "group",
#           "confidence_score": 0.593595624
#         },
#         {
#           "name": "XXV Olympiad Barcelona",
#           "category": "group",
#           "confidence_score": 0.5632660091
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091631",
#     "label_en": "BARCELONA '92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.045",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BARCELONA",
#           "category": "group",
#           "confidence_score": 0.593595624
#         },
#         {
#           "name": "XXV Olympiad Barcelona",
#           "category": "group",
#           "confidence_score": 0.5632660091
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091632",
#     "label_en": "BARCELONA 92:  Games of the XXV Olympiad Barcelona 1992",
#     "inventory_number": "1998.043",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BARCELONA",
#           "category": "group",
#           "confidence_score": 0.8035004139
#         },
#         {
#           "name": "XXV Olympiad Barcelona",
#           "category": "group",
#           "confidence_score": 0.584798644
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091633",
#     "label_en": "Barcelona Blue #14 (Mountain Drawing)",
#     "inventory_number": "1996.073",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona Blue",
#           "category": "group",
#           "confidence_score": 0.8553436399
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091634",
#     "label_en": "Barcelona Blue #7 (Mountain Drawing)",
#     "inventory_number": "1996.071",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona Blue",
#           "category": "group",
#           "confidence_score": 0.8863239884
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091635",
#     "label_en": "Barcelona Blue #8 (Mountain Drawing)",
#     "inventory_number": "1996.072",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona Blue",
#           "category": "group",
#           "confidence_score": 0.8720289767
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091636",
#     "label_en": "Barcelona Blue #9 (Mountain Drawing)",
#     "inventory_number": "1996.074",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Barcelona Blue",
#           "category": "group",
#           "confidence_score": 0.8726813197
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091637",
#     "label_en": "Barenaked Ladies",
#     "inventory_number": "2001.108",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091643",
#     "label_en": "Battle Scene from the Sino-Japanese War",
#     "inventory_number": "1972.048",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091644",
#     "label_en": "Be A Good Neighbor-Check Out John Hartford Live from Mountain Stage, Blue Plate Music - BPM-401",
#     "inventory_number": "2001.022",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "John Hartford",
#           "category": "name",
#           "confidence_score": 0.8199299276
#         },
#         {
#           "name": "Mountain Stage",
#           "category": "place",
#           "confidence_score": 0.5873829424
#         },
#         {
#           "name": "Blue Plate",
#           "category": "place",
#           "confidence_score": 0.7538891733
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091645",
#     "label_en": "Beast, from The Marriage of Venus and Mars",
#     "inventory_number": "2016.004",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Marriage of Venus",
#           "category": "group",
#           "confidence_score": 0.7311982612
#         },
#         {
#           "name": "Mars",
#           "category": "group",
#           "confidence_score": 0.5033589005
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091646",
#     "label_en": "Bechtold (Dedicated book)",
#     "inventory_number": "1996.032",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bechtold",
#           "category": "name",
#           "confidence_score": 0.9135216475
#         },
#         {
#           "name": "Dedicated book",
#           "category": "group",
#           "confidence_score": 0.7519356608
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091647",
#     "label_en": "Ben Folds Five, Jude, May 30",
#     "inventory_number": "2000.031",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Ben Folds",
#           "category": "name",
#           "confidence_score": 0.9499144256
#         },
#         {
#           "name": "Jude",
#           "category": "name",
#           "confidence_score": 0.7599830031
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091648",
#     "label_en": "Ben Harper and the Innocent Criminals",
#     "inventory_number": "2001.122",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Ben Harper",
#           "category": "name",
#           "confidence_score": 0.9510113001
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091649",
#     "label_en": "Berkhampstead - Herts.",
#     "inventory_number": "1979.0131",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Berkhampstead",
#           "category": "place",
#           "confidence_score": 0.4688213468
#         },
#         {
#           "name": "Herts",
#           "category": "group",
#           "confidence_score": 0.6593085527
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091650",
#     "label_en": "Best of the best showcase April 28,1999",
#     "inventory_number": "2000.012",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091651",
#     "label_en": "Bhutanese tangkha of Chenrazig, the Bodhisattva of Compassion",
#     "inventory_number": "2004.043",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bhutanese",
#           "category": "place",
#           "confidence_score": 0.7677807212
#         },
#         {
#           "name": "Chenrazig",
#           "category": "place",
#           "confidence_score": 0.5543624163
#         },
#         {
#           "name": "Bodhisattva of Compassion",
#           "category": "group",
#           "confidence_score": 0.7430642049
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091652",
#     "label_en": "Bijou Theatre",
#     "inventory_number": "2001.092",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bijou Theatre",
#           "category": "group",
#           "confidence_score": 0.6250170171
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091653",
#     "label_en": "BIll Kirchen and Too Much Full Featuring Johnny and Jack",
#     "inventory_number": "2001.153",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "BIll Kirchen",
#           "category": "name",
#           "confidence_score": 0.8642571867
#         },
#         {
#           "name": "Johnny",
#           "category": "name",
#           "confidence_score": 0.5202775002
#         },
#         {
#           "name": "Jack",
#           "category": "name",
#           "confidence_score": 0.6613280177
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091654",
#     "label_en": "Bill Monroe Live From Mountain Stage",
#     "inventory_number": "2000.025",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bill Monroe",
#           "category": "name",
#           "confidence_score": 0.9414973557
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091655",
#     "label_en": "Birds and Pine Tree",
#     "inventory_number": "1979.01",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091656",
#     "label_en": "Birthweek 2000: Guerrilla monster and BR2 present \"Elvis meets the Beatles\"",
#     "inventory_number": "2001.088",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Elvis",
#           "category": "name",
#           "confidence_score": 0.6291120648
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091657",
#     "label_en": "Bisbee's Comedians",
#     "inventory_number": "2001.174",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bisbee",
#           "category": "group",
#           "confidence_score": 0.7296882272
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091658",
#     "label_en": "Bize II, from American Abstract Artists 75th Anniversary Print Portfolio",
#     "inventory_number": "2015.038n",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bize II",
#           "category": "group",
#           "confidence_score": 0.587120533
#         },
#         {
#           "name": "American Abstract Artists",
#           "category": "group",
#           "confidence_score": 0.6716475785
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091659",
#     "label_en": "Blue glass object with stopper",
#     "inventory_number": "1979.1000P",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091660",
#     "label_en": "Blue grass Festival Ryman Auditorium, May 7-8-9 1999, Hatch Show Print Poster",
#     "inventory_number": "2000.009",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Hatch",
#           "category": "name",
#           "confidence_score": 0.4638870656
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091662",
#     "label_en": "Blue Mountain",
#     "inventory_number": "2001.102",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Blue Mountain",
#           "category": "place",
#           "confidence_score": 0.3706608862
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091663",
#     "label_en": "Blue Surge",
#     "inventory_number": "1984.015",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091664",
#     "label_en": "Bluebird Cafe Presents The Rounds Bros. with Ellen Britton, Sunday March 12",
#     "inventory_number": "2001.033",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bluebird Cafe",
#           "category": "group",
#           "confidence_score": 0.7429014146
#         },
#         {
#           "name": "Rounds Bros",
#           "category": "group",
#           "confidence_score": 0.7720320225
#         },
#         {
#           "name": "Ellen Britton",
#           "category": "name",
#           "confidence_score": 0.9703733623
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091665",
#     "label_en": "Bluegrass Festival, The Karl Shiflett and Big Country Show, May 28-30, 1999",
#     "inventory_number": "2000.038",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bluegrass Festival",
#           "category": "group",
#           "confidence_score": 0.5796358883
#         },
#         {
#           "name": "Karl Shiflett",
#           "category": "name",
#           "confidence_score": 0.9522703588
#         },
#         {
#           "name": "Big Country Show",
#           "category": "group",
#           "confidence_score": 0.557348907
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091666",
#     "label_en": "Bluegrass Night at the Ryman",
#     "inventory_number": "2001.106",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Ryman",
#           "category": "group",
#           "confidence_score": 0.5382829905
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091667",
#     "label_en": "Bob Delevante Porchlight Record, Dec 3,1999, Hatch Show Print Poster",
#     "inventory_number": "2000.081",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Bob Delevante Porchlight",
#           "category": "name",
#           "confidence_score": 0.732592086
#         },
#         {
#           "name": "Hatch",
#           "category": "name",
#           "confidence_score": 0.8385927677
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091668",
#     "label_en": "Bombastic Plastic",
#     "inventory_number": "2001.134",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091669",
#     "label_en": "Bomber Records presents Dispatch",
#     "inventory_number": "2001.016",
#     "named_entities": {
#       "entities": [
#         {
#           "name": "Dispatch",
#           "category": "group",
#           "confidence_score": 0.6728092432
#         }
#       ]
#     }
#   },
#   {
#     "qid": "Q105091670",
#     "label_en": "Bomber Records Presents Dispatch",
#     "inventory_number": "2001.08",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091671",
#     "label_en": "Bomber Records Presents Dispatch",
#     "inventory_number": "2001.079",
#     "named_entities": {
#       "entities": []
#     }
#   },
#   {
#     "qid": "Q105091672",
#     "label_en": "Bomber records presents Dispatch- Coming Soon",
#     "inventory_number": "2001.053",
#     "named_entities": {
#       "entities": []
#     }
#   }
# ]

# %% [markdown]
# Try Stanza, NER by Stanford

# %% [markdown]
# ## Combined code

# %%
# WARNING: there is a daily limit for the Parallel Dots free tier, so don't run this script over and over
# or with a large dataset without commenting out the Parallel Dots part of the code
# Free tier daily limits are 2000 hits, rate limit 60 hits per minute

import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
''' These downloads only need to be done once, so that's why they are commented out now
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
'''
import spacy
from spacy import displacy
from collections import Counter
# first had to execute at command line:
''' Also a one-time download
python -m spacy download en_core_web_sm
'''
import en_core_web_sm
nlp = en_core_web_sm.load()

# Note: ParallelDots is a commercial product with a free tier. But it requires an account and API key to use.
import paralleldots
key = load_credential('paralleldots_api_key.txt', 'home')
paralleldots.set_api_key(key)

filename = 'works_multiprop.csv'
works = read_dict(filename)
output_list = []

for work in works[0:1000]:
    print('raw text:', work['label_en'])
    work_dict = {'qid': work['qid'], 'label_en': work['label_en'], 'inventory_number': work['inventory_number']}
    
    # NLP
    ne_list = []
    # https://stackoverflow.com/questions/31836058/nltk-named-entity-recognition-to-a-python-list
    tokens = nltk.word_tokenize(work['label_en'])
    # print('tokens:', tokens)
    tagged_tokens = nltk.pos_tag(tokens)
    # print('tagged:', tagged_tokens)
    named_entity_chunks = nltk.ne_chunk(tagged_tokens)
    # print('NE chunks:', named_entity_chunks)
    
    for chunk in named_entity_chunks:
        if hasattr(chunk, 'label'):
            ne_dict = {'label': chunk.label()}
            # A chunk is some kind of iterable of tuples
            # Each tuple contains (word, noun_descriptor)
            ne_string = chunk[0][0] # 0th tuple, word
            # Iterate through the rest of the tuples in the chunk
            for additional_tuple in chunk[1:len(chunk)]:
                ne_string += ' ' + additional_tuple[0]
            ne_dict['string'] = ne_string
            ne_list.append(ne_dict)

            # print(chunk.label(), ' '.join(c[0] for c in chunk))
    # print('NE list:', ne_list)
    work_dict['nlp'] = ne_list
    # print(json.dumps(work_dict, indent = 2))
    
    # Spacy
    # See https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da 
    # for codes used in output by Spacy
    ne_list = []
    result = nlp(work['label_en'])
    for entity in result.ents:
        ne_list.append({'label': entity.label_, 'string': entity.text})
    work_dict['spacy'] = ne_list
    
    # Parallel Dots API
    named_entities = paralleldots.ner(work['label_en'])
    work_dict['parallel_dots'] = named_entities
    sleep(dots_sleep) # This is a delay to prevent hitting the API to frequently and getting blocked

    # Append all of the collected data to the accumulation list
    output_list.append(work_dict)
    
output_text = json.dumps(output_list, indent = 2)

out_file_path = 'named_er.json'
with open(out_file_path, 'wt', encoding='utf-8') as file_object:
    file_object.write(output_text)
print('done')
